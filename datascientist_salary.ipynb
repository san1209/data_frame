# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-423ba925-d366-4c75-87b1-5f02577b40c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-423ba925-d366-4c75-87b1-5f02577b40c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Myntra_fashion_products.csv to Myntra_fashion_products.csv

# %% [markdown]
# # New section

# %%
import numpy as np
from numpy import average
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statistics as st
import csv

# %%
data = pd.read_csv("Myntra_fashion_products.csv")

# %%
data
# Out:
#                                                     name  ...  gender
# 0      DKNY Unisex Black & Grey Printed Medium Trolle...  ...  Unisex
# 1      EthnoVogue Women Beige & Grey Made to Measure ...  ...   Women
# 2      SPYKAR Women Pink Alexa Super Skinny Fit High-...  ...   Women
# 3      Raymond Men Blue Self-Design Single-Breasted B...  ...     Men
# 4      Parx Men Brown & Off-White Slim Fit Printed Ca...  ...     Men
# ...                                                  ...  ...     ...
# 12486  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...  ...     Men
# 12487                 Mochi Women Gold-Toned Solid Heels  ...   Women
# 12488  612 league Girls Navy Blue & White Printed Reg...  ...   Girls
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...  ...     Men
# 12490  Pepe Jeans Men Black & Grey Striped Polo Colla...  ...     Men
#
# [12491 rows x 10 columns]

# %%
y=data.sku
x=data.mpn
z=data.price

# %%
plt.plot(x)

plt.plot(y)

plt.xlabel("Stock keeping unit")
plt.ylabel("Manufacturer Part Number")




plt.legend(["blue", "green"])

plt.show()

# %%
plt.plot(y)


plt.ylabel("Manufacturer Part Number")




plt.legend(["blue", "green"])

plt.show()

# %%
plt.plot(z)

plt.show()

# %%
plt.plot(x, y)

plt.xlabel("Stock keeping unit")
plt.ylabel("Manufacturer Part Number")

plt.grid()

plt.show()

# %%
plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
plt.plot(x, y)

plt.title("Myntra fashion logistcs")
plt.xlabel("Stock keeping unit")
plt.ylabel("Manufacturer Part Number")


plt.show()

# %%
plt.plot(x)
plt.plot(y)
  
# Function add a legend  
plt.legend(["blue", "green"], loc ="lower right")
  
# function to show the plot
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y) 

ax.set_xticks(ax.get_xticks()[::4]) #you are setting the ticks of the x-axis picking 1 data every 4 using the property of the list

# %%
import numpy as np
import matplotlib.pyplot as plt
  
# X-axis values
x = np.arange(5)
  
# Y-axis values
y1 = [1, 2, 3, 4, 5]
  
# Y-axis values 
y2 = [1, 4, 9, 16, 25]
  
# Function to plot  
plt.plot(x, y1, label ='Numbers')
plt.plot(x, y2, label ='Square of numbers')
  
# Function add a legend  
plt.legend()
  
# function to show the plot
plt.show()
